# %% [markdown]
# # Dataset Exploration - Title (Also Known As)
#
# This notebook will assist with exploring the data set to understand the data that it contains.

# %%
import pandas as pd

# load the title basics dataset
df = pd.read_csv('./data/title.akas.tsv', index_col=None, na_values=['NA'],
sep='\t',low_memory=False)

# %%
# display row and column counts
df.shape
# Out:
# (3384139, 8)

# %%
# display column names
df.columns.tolist()
# Out:
# ['titleId',
#  'ordering',
#  'title',
#  'region',
#  'language',
#  'types',
#  'attributes',
#  'isOriginalTitle']

# %%
from IPython.display import display

# load the field descriptions
fld_dicitonary = pd.read_csv("./data/title_akas_flddesc.csv", index_col=0, sep='^')
pd.set_option('display.max_colwidth', -1)

# display descriptions
fld_dicitonary
# Out:
#                  fldType  \
# fldName
# titleId          string
# ordering         integer
# title            string
# region           string
# language         string
# types            array
# attributes       array
# isOriginalTitle  boolean
#
#                                                                                                                                                                                                                                              fldDesc
# fldName
# titleId          a tconst, an alphanumeric unique identifier of the title
# ordering         a number to uniquely identify rows for a given titleId
# title            the localized title
# region           the region for this version of the title
# language         the language of the title
# ...

# %%
# display the first 25 rows
df.head(25)
# Out:
#       titleId  ordering                      title region language  \
# 0   tt0000001  1         Carmencita - spanyol tánc  HU     \N
# 1   tt0000001  2         Карменсита                 RU     \N
# 2   tt0000001  3         Carmencita                 US     \N
# 3   tt0000001  4         Carmencita                 \N     \N
# 4   tt0000002  1         Le clown et ses chiens     \N     \N
# 5   tt0000002  2         A bohóc és kutyái          HU     \N
# 6   tt0000002  3         Le clown et ses chiens     FR     \N
# 7   tt0000002  4         The Clown and His Dogs     US     \N
# 8   tt0000002  5         Клоун и его собаки         RU     \N
# 9   tt0000003  1         Szegény Pierrot            HU     \N
# 10  tt0000003  2         Бедный Пьеро               RU     \N
# 11  tt0000003  3         Pauvre Pierrot             \N     \N
# 12  tt0000003  4         Poor Pierrot               \N     \N
# 13  tt0000003  5         Pauvre Pierrot             FR     \N
# ...

# %%
# display the last 25 rows
df.tail(25)
# Out:
#            titleId  ordering  \
# 3384114  tt8707444  2
# 3384115  tt8707444  3
# 3384116  tt8707464  1
# 3384117  tt8707464  2
# 3384118  tt8707464  3
# 3384119  tt8707510  1
# 3384120  tt8707510  2
# 3384121  tt8707510  3
# 3384122  tt8707546  1
# 3384123  tt8707546  2
# 3384124  tt8707688  1
# 3384125  tt8707688  2
# 3384126  tt8707688  3
# 3384127  tt8707688  4
# 3384128  tt8707750  1
# 3384129  tt8707750  2
# 3384130  tt8708694  1
# 3384131  tt8708694  2
# 3384132  tt8708708  1
# 3384133  tt8708708  2
# 3384134  tt8708708  3
# 3384135  tt8708838  1
# 3384136  tt8708838  2
# 3384137  tt8709320  1
# 3384138  tt8709320  2
#
#                                                                                                                          title  \
# 3384114  Losing Your Virginity To Mom POV
# 3384115  Mommy Steals Your Virginity
# 3384116  Sweet Tooth
# 3384117  Guloso
# 3384118  Sweet Tooth
# 3384119  The Order
# 3384120  O Pedido
# 3384121  The Order
# ...
