# %% [markdown]
# # Dataset Exploration - Names (Basic)
#
# This notebook will assist with exploring the data set to understand the data that it contains.

# %%
import pandas as pd

# load the title basics dataset
df = pd.read_csv('./data/name.basics.tsv', index_col=None, na_values=['NA'],
sep='\t',low_memory=False)

# %%
# display row and column counts
df.shape
# Out:
# (8726558, 6)

# %%
# display column names
df.columns.tolist()
# Out:
# ['nconst',
#  'primaryName',
#  'birthYear',
#  'deathYear',
#  'primaryProfession',
#  'knownForTitles']

# %%
from IPython.display import display

# load the field descriptions
fld_dicitonary = pd.read_csv("./data/name_basics_flddesc.csv", index_col=0, sep='^')
pd.set_option('display.max_colwidth', -1)

# display descriptions
fld_dicitonary
# Out:
#                             fldType  \
# fldName
# nconst             string
# primaryName        string
# birthYear          NaN
# deathYear          NaN
# primaryProfession  array of strings
# knownForTitles     array of tconsts
#
#                                                              fldDesc
# fldName
# nconst             alphanumeric unique identifier of the name/person
# primaryName        name by which the person is most often credited
# birthYear          in YYYY format
# deathYear          in YYYY format if applicable, else '\N'
# primaryProfession  the top-3 professions of the person
# knownForTitles     titles the person is known for

# %%
# display the first 25 rows
df.head(25)
# Out:
#        nconst          primaryName birthYear deathYear  \
# 0   nm0000001  Fred Astaire         1899      1987
# 1   nm0000002  Lauren Bacall        1924      2014
# 2   nm0000003  Brigitte Bardot      1934      \N
# 3   nm0000004  John Belushi         1949      1982
# 4   nm0000005  Ingmar Bergman       1918      2007
# 5   nm0000006  Ingrid Bergman       1915      1982
# 6   nm0000007  Humphrey Bogart      1899      1957
# 7   nm0000008  Marlon Brando        1924      2004
# 8   nm0000009  Richard Burton       1925      1984
# 9   nm0000010  James Cagney         1899      1986
# 10  nm0000011  Gary Cooper          1901      1961
# 11  nm0000012  Bette Davis          1908      1989
# 12  nm0000013  Doris Day            1922      \N
# 13  nm0000014  Olivia de Havilland  1916      \N
# 14  nm0000015  James Dean           1931      1955
# 15  nm0000016  Georges Delerue      1925      1992
# 16  nm0000017  Marlene Dietrich     1901      1992
# ...

# %%
# display the last 25 rows
df.tail(25)
# Out:
#             nconst                primaryName birthYear deathYear  \
# 8726533  nm9977475  Tom Anthony Ashley Mellor  \N        \N
# 8726534  nm9977476  Brenda Tomchak             \N        \N
# 8726535  nm9977479  Richard Ledgett            \N        \N
# 8726536  nm9977481  Natalia Marty              \N        \N
# 8726537  nm9977482  Theresa Morin              \N        \N
# 8726538  nm9977483  Gaston Talavera            \N        \N
# 8726539  nm9977484  Frida Montes               \N        \N
# 8726540  nm9977485  Lissú Pineda               \N        \N
# 8726541  nm9977486  Ramiro Galván              \N        \N
# 8726542  nm9977487  Scott Uehlinger            \N        \N
# 8726543  nm9977488  Anthony Gabriel Quinonez   \N        \N
# 8726544  nm9977491  Thomas                     \N        \N
# 8726545  nm9977492  Tim Smith                  \N        \N
# 8726546  nm9977493  Karissa Pukas              \N        \N
# ...

# %%
df.tail(25)
# Out:
#             nconst                primaryName birthYear deathYear  \
# 8726533  nm9977475  Tom Anthony Ashley Mellor  \N        \N
# 8726534  nm9977476  Brenda Tomchak             \N        \N
# 8726535  nm9977479  Richard Ledgett            \N        \N
# 8726536  nm9977481  Natalia Marty              \N        \N
# 8726537  nm9977482  Theresa Morin              \N        \N
# 8726538  nm9977483  Gaston Talavera            \N        \N
# 8726539  nm9977484  Frida Montes               \N        \N
# 8726540  nm9977485  Lissú Pineda               \N        \N
# 8726541  nm9977486  Ramiro Galván              \N        \N
# 8726542  nm9977487  Scott Uehlinger            \N        \N
# 8726543  nm9977488  Anthony Gabriel Quinonez   \N        \N
# 8726544  nm9977491  Thomas                     \N        \N
# 8726545  nm9977492  Tim Smith                  \N        \N
# 8726546  nm9977493  Karissa Pukas              \N        \N
# ...
