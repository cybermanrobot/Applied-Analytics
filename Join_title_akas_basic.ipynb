# %%
import pandas as pd

#Load Datasets

## load the title basics dataset
title_akas_df = pd.read_csv('./data/title.akas.tsv', index_col=None, na_values=['NA'],sep='\t',low_memory=False)


## load the title basics dataset
title_basics_df = pd.read_csv('./data/title.basics.tsv', index_col=None, na_values=['NA'],
sep='\t',low_memory=False)

# %%
# Filter data for region US
title_akas_us=title_akas_df[title_akas_df.region=='US']

# %%
# Fiter only movies
title_basics_df_movie=title_basics_df.groupby('titleType').get_group('movie').copy()
#Filter only non adult movies
title_basics_df_movie= title_basics_df_movie[title_basics_df_movie.isAdult=='0'].copy()

# %%
#  rename columns to merge
title_akas_us.rename(columns={"titleId": "tconst"},inplace=True)
display(title_akas_us.head(5))
display(title_basics_df_movie.head(5))
# Out:
# C:\Users\guptav4\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#        tconst  ordering                   title region language        types  \
# 2   tt0000001         3              Carmencita     US       \N           \N
# 7   tt0000002         4  The Clown and His Dogs     US       \N           \N
# 19  tt0000005         1     Blacksmithing Scene     US       \N  alternative
# 22  tt0000005         4     Blacksmith Scene #1     US       \N  alternative
# 23  tt0000005         5           Blacksmithing     US       \N           \N
#
#                     attributes isOriginalTitle
# 2                           \N               0
# 7        literal English title               0
# 19                          \N               0
# 22                          \N               0
# 23  informal alternative title               0
#         tconst titleType                   primaryTitle  \
# 8    tt0000009     movie                     Miss Jerry
# 145  tt0000147     movie  The Corbett-Fitzsimmons Fight
# 332  tt0000335     movie          Soldiers of the Cross
# 499  tt0000502     movie                       Bohemios
# 571  tt0000574     movie    The Story of the Kelly Gang
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 8                       Miss Jerry       0      1894      \N             45
# 145  The Corbett-Fitzsimmons Fight       0      1897      \N             20
# 332          Soldiers of the Cross       0      1900      \N             \N
# 499                       Bohemios       0      1905      \N            100
# 571    The Story of the Kelly Gang       0      1906      \N             70
#
#                      genres
# 8                   Romance
# 145  Documentary,News,Sport
# 332         Biography,Drama
# 499                      \N
# 571   Biography,Crime,Drama

# %%
#result dataset for non adult movies only for region US
df_us_movies_non_adult_result = pd.merge(title_akas_us,
                 title_basics_df_movie,
                 on='tconst', 
                 how='inner')

# %%
# This is in WIP, we may have to remove duplicates by primary title
########################################################################
len(df_us_movies_non_adult_result)
# Out:
# 171832

# %%
df_us_movies_non_adult_result.head(20)
# Out:
#        tconst  ordering                                  title region  \
# 0   tt0000009         3                             Miss Jerry     US
# 1   tt0000147         1          The Corbett-Fitzsimmons Fight     US
# 2   tt0000630         4                                 Hamlet     US
# 3   tt0000679         1         The Fairylogue and Radio-Plays     US
# 4   tt0000886         2              Hamlet, Prince of Denmark     US
# 5   tt0000891         2            The Witch and the Bicyclist     US
# 6   tt0000891         5              Cycle Rider and the Witch     US
# 7   tt0001101         2             Abraham Lincoln's Clemency     US
# 8   tt0001159         1                 The Connecticut Yankee     US
# 9   tt0001186         3        Dorothy and the Scarecrow in Oz     US
# 10  tt0001230         1                          Gentleman Joe     US
# 11  tt0001285         1  Forty Years in the Land of the Midian     US
# 12  tt0001285         3                  The Victory of Israel     US
# 13  tt0001285         5                      The Life of Moses     US
# 14  tt0001285         6                   The Plagues of Egypt     US
# 15  tt0001285         7                      The Promised Land     US
# 16  tt0001422         1                      Trail to the West     US
# 17  tt0001482         1                  As in a Looking Glass     US
# 18  tt0001498         3                The Battle of Trafalgar     US
# 19  tt0001515         1                              The Brand     US
#
#    language types           attributes isOriginalTitle titleType  \
# 0        \N    \N                   \N               0     movie
# 1        \N    \N                   \N               0     movie
# 2        \N    \N                   \N               0     movie
# 3        \N    \N                   \N               0     movie
# 4        \N    \N                   \N               0     movie
# 5        \N    \N                   \N               0     movie
# 6        \N    \N                   \N               0     movie
# 7        \N    \N                   \N               0     movie
# 8        \N    \N                   \N               0     movie
# 9        \N    \N                   \N               0     movie
# 10       \N    \N                   \N               0     movie
# 11       \N    \N    second part title               0     movie
# 12       \N    \N  fourth season title               0     movie
# 13       \N    \N                   \N               0     movie
# 14       \N    \N     third part title               0     movie
# 15       \N    \N   fifth season title               0     movie
# 16       \N    \N                   \N               0     movie
# 17       \N    \N                   \N               0     movie
# 18       \N    \N                   \N               0     movie
# 19       \N    \N                   \N               0     movie
#
#                        primaryTitle                    originalTitle isAdult  \
# 0                        Miss Jerry                       Miss Jerry       0
# 1     The Corbett-Fitzsimmons Fight    The Corbett-Fitzsimmons Fight       0
# 2                            Hamlet                           Amleto       0
# 3    The Fairylogue and Radio-Plays   The Fairylogue and Radio-Plays       0
# 4         Hamlet, Prince of Denmark                           Hamlet       0
# 5         Cycle Rider and the Witch              Heksen og cyklisten       0
# 6         Cycle Rider and the Witch              Heksen og cyklisten       0
# 7        Abraham Lincoln's Clemency       Abraham Lincoln's Clemency       0
# 8            The Connecticut Yankee           The Connecticut Yankee       0
# 9   Dorothy and the Scarecrow in Oz  Dorothy and the Scarecrow in Oz       0
# 10                    Gentleman Joe                    Gentleman Joe       0
# 11                The Life of Moses                The Life of Moses       0
# 12                The Life of Moses                The Life of Moses       0
# 13                The Life of Moses                The Life of Moses       0
# 14                The Life of Moses                The Life of Moses       0
# 15                The Life of Moses                The Life of Moses       0
# 16                Trail to the West                Trail to the West       0
# 17            As in a Looking Glass            As in a Looking Glass       0
# 18          The Battle of Trafalgar          The Battle of Trafalgar       0
# 19                        The Brand                        The Brand       0
#
#    startYear endYear runtimeMinutes                  genres
# 0       1894      \N             45                 Romance
# 1       1897      \N             20  Documentary,News,Sport
# 2       1908      \N             \N                   Drama
# 3       1908      \N            120       Adventure,Fantasy
# 4       1910      \N             \N                   Drama
# 5       1909      \N             \N                      \N
# 6       1909      \N             \N                      \N
# 7       1910      \N             \N                      \N
# 8       1910      \N             \N                      \N
# 9       1910      \N             \N                      \N
# 10      1910      \N             \N                      \N
# 11      1909      \N             \N  Biography,Drama,Family
# 12      1909      \N             \N  Biography,Drama,Family
# 13      1909      \N             \N  Biography,Drama,Family
# 14      1909      \N             \N  Biography,Drama,Family
# 15      1909      \N             \N  Biography,Drama,Family
# 16      1910      \N             \N                      \N
# 17      1911      \N             \N                   Drama
# 18      1911      \N             51                     War
# 19      1911      \N             \N                      \N

# %%
df_us_movies_non_adult_result.columns
# Out:
# Index(['tconst', 'ordering', 'title', 'region', 'language', 'types',
#        'attributes', 'isOriginalTitle', 'titleType', 'primaryTitle',
#        'originalTitle', 'isAdult', 'startYear', 'endYear', 'runtimeMinutes',
#        'genres'],
#       dtype='object')

# %%
# Get dataset cleaned up for columns we may want to use
df_us_movies_non_adult_result=df_us_movies_non_adult_result[['tconst','primaryTitle','startYear','runtimeMinutes','genres']].copy()

# %%
len(df_us_movies_non_adult_result)
# Out:
# 171832

# %%
df_us_movies_non_adult_result.head(25)
# Out:
#        tconst                     primaryTitle startYear runtimeMinutes  \
# 0   tt0000009                       Miss Jerry      1894             45
# 1   tt0000147    The Corbett-Fitzsimmons Fight      1897             20
# 2   tt0000630                           Hamlet      1908             \N
# 3   tt0000679   The Fairylogue and Radio-Plays      1908            120
# 4   tt0000886        Hamlet, Prince of Denmark      1910             \N
# 5   tt0000891        Cycle Rider and the Witch      1909             \N
# 6   tt0000891        Cycle Rider and the Witch      1909             \N
# 7   tt0001101       Abraham Lincoln's Clemency      1910             \N
# 8   tt0001159           The Connecticut Yankee      1910             \N
# 9   tt0001186  Dorothy and the Scarecrow in Oz      1910             \N
# 10  tt0001230                    Gentleman Joe      1910             \N
# 11  tt0001285                The Life of Moses      1909             \N
# 12  tt0001285                The Life of Moses      1909             \N
# 13  tt0001285                The Life of Moses      1909             \N
# 14  tt0001285                The Life of Moses      1909             \N
# 15  tt0001285                The Life of Moses      1909             \N
# 16  tt0001422                Trail to the West      1910             \N
# 17  tt0001482            As in a Looking Glass      1911             \N
# 18  tt0001498          The Battle of Trafalgar      1911             51
# 19  tt0001515                        The Brand      1911             \N
# 20  tt0001530           The Bushranger's Bride      1911             \N
# 21  tt0001569                The Daddy's Dream      1911             \N
# 22  tt0001586                     A Dog's Tale      1911             \N
# 23  tt0001628             The Four Poster Pest      1911             \N
# 24  tt0001692                 The Great Moment      1911             \N
#
#                     genres
# 0                  Romance
# 1   Documentary,News,Sport
# 2                    Drama
# 3        Adventure,Fantasy
# 4                    Drama
# 5                       \N
# 6                       \N
# 7                       \N
# 8                       \N
# 9                       \N
# 10                      \N
# 11  Biography,Drama,Family
# 12  Biography,Drama,Family
# 13  Biography,Drama,Family
# 14  Biography,Drama,Family
# 15  Biography,Drama,Family
# 16                      \N
# 17                   Drama
# 18                     War
# 19                      \N
# 20                   Drama
# 21                      \N
# 22                      \N
# 23                      \N
# 24                   Drama

# %%
df_us_movies_non_adult_result.head(20)
# Out:
#        tconst                     primaryTitle startYear runtimeMinutes  \
# 0   tt0000009                       Miss Jerry      1894             45
# 1   tt0000147    The Corbett-Fitzsimmons Fight      1897             20
# 2   tt0000630                           Hamlet      1908             \N
# 3   tt0000679   The Fairylogue and Radio-Plays      1908            120
# 4   tt0000886        Hamlet, Prince of Denmark      1910             \N
# 5   tt0000891        Cycle Rider and the Witch      1909             \N
# 6   tt0000891        Cycle Rider and the Witch      1909             \N
# 7   tt0001101       Abraham Lincoln's Clemency      1910             \N
# 8   tt0001159           The Connecticut Yankee      1910             \N
# 9   tt0001186  Dorothy and the Scarecrow in Oz      1910             \N
# 10  tt0001230                    Gentleman Joe      1910             \N
# 11  tt0001285                The Life of Moses      1909             \N
# 12  tt0001285                The Life of Moses      1909             \N
# 13  tt0001285                The Life of Moses      1909             \N
# 14  tt0001285                The Life of Moses      1909             \N
# 15  tt0001285                The Life of Moses      1909             \N
# 16  tt0001422                Trail to the West      1910             \N
# 17  tt0001482            As in a Looking Glass      1911             \N
# 18  tt0001498          The Battle of Trafalgar      1911             51
# 19  tt0001515                        The Brand      1911             \N
#
#                     genres
# 0                  Romance
# 1   Documentary,News,Sport
# 2                    Drama
# 3        Adventure,Fantasy
# 4                    Drama
# 5                       \N
# 6                       \N
# 7                       \N
# 8                       \N
# 9                       \N
# 10                      \N
# 11  Biography,Drama,Family
# 12  Biography,Drama,Family
# 13  Biography,Drama,Family
# 14  Biography,Drama,Family
# 15  Biography,Drama,Family
# 16                      \N
# 17                   Drama
# 18                     War
# 19                      \N

# %%
# remove duplicates
df_us_movies_non_adult_result2=df_us_movies_non_adult_result.drop_duplicates()

# %%
#number after duplicates removed
len(df_us_movies_non_adult_result2)
# Out:
# 149352

# %%
df_us_movies_non_adult_result2
# Out:
#            tconst                                       primaryTitle  \
# 0       tt0000009                                         Miss Jerry
# 1       tt0000147                      The Corbett-Fitzsimmons Fight
# 2       tt0000630                                             Hamlet
# 3       tt0000679                     The Fairylogue and Radio-Plays
# 4       tt0000886                          Hamlet, Prince of Denmark
# 5       tt0000891                          Cycle Rider and the Witch
# 7       tt0001101                         Abraham Lincoln's Clemency
# 8       tt0001159                             The Connecticut Yankee
# 9       tt0001186                    Dorothy and the Scarecrow in Oz
# 10      tt0001230                                      Gentleman Joe
# 11      tt0001285                                  The Life of Moses
# 16      tt0001422                                  Trail to the West
# 17      tt0001482                              As in a Looking Glass
# 18      tt0001498                            The Battle of Trafalgar
# 19      tt0001515                                          The Brand
# 20      tt0001530                             The Bushranger's Bride
# 21      tt0001569                                  The Daddy's Dream
# 22      tt0001586                                       A Dog's Tale
# 23      tt0001628                               The Four Poster Pest
# 24      tt0001692                                   The Great Moment
# 25      tt0001706                           The Infant at Snakeville
# 26      tt0001731                                   The Convict Hero
# 27      tt0001892                                     Den sorte drøm
# 28      tt0001911                                        Nell Gwynne
# 29      tt0001914                              The Devil's Assistant
# 31      tt0001964                                      The Traitress
# 32      tt0001998             The Adventures of Lieutenant Petrosino
# 33      tt0002001                     The Alaska-Siberian Expedition
# 34      tt0002031                                     As You Like It
# 35      tt0002039                        Atop of the World in Motion
# ...           ...                                                ...
# 171795  tt8532400                                           Man Aive
# 171796  tt8537064                                   Disco Fever 1977
# 171797  tt8537490                    L'amore è cieco [Love is Blind]
# 171798  tt8550840            Untitled Progressive School Documentary
# 171799  tt8571958                                      Clown Footage
# 171800  tt8591654               Untitled Ted Bundy Had a Son Prequel
# 171801  tt8592222                                 Teen Drone Stalker
# 171802  tt8595626                           Le Gardien du Non-Retour
# 171803  tt8598334                                     West End Girls
# 171804  tt8598532                                  Killer Single Dad
# 171805  tt8600892                                    The Friend Zone
# 171806  tt8610036                                              Alone
# 171807  tt8614536                                          Farmlands
# 171808  tt8618118                                      Plagi Breslau
# 171809  tt8618244         Silverstein: Decade Live at The El Mocambo
# 171810  tt8619974                                     The Way Home 2
# 171813  tt8619980                                       The Way Home
# 171814  tt8656640                                          Rub & Tug
# 171815  tt8657154                            The Story of Darksiders
# 171816  tt8682654  I saw a little bird flying over a psychiatric ...
# 171818  tt8685168                                      Story at Dawn
# 171819  tt8691450                                        Sacred Play
# 171820  tt8701708              Star Wars Episode I: Fall of the Jedi
# 171821  tt8705266                                     Mischief Night
# 171822  tt8726106                                   Sinfonia Caipira
# 171823  tt8728782                        The Mirror and the Scaffold
# 171824  tt8729292                                     Jesa-ui gongpo
# 171828  tt8741974                                  West of Littleton
# 171830  tt8749144                             Flame: Maximum Carnage
# 171831  tt8750848                                   Whoismisterputin
#
#        startYear runtimeMinutes                   genres
# 0           1894             45                  Romance
# 1           1897             20   Documentary,News,Sport
# 2           1908             \N                    Drama
# 3           1908            120        Adventure,Fantasy
# 4           1910             \N                    Drama
# 5           1909             \N                       \N
# 7           1910             \N                       \N
# 8           1910             \N                       \N
# 9           1910             \N                       \N
# 10          1910             \N                       \N
# 11          1909             \N   Biography,Drama,Family
# 16          1910             \N                       \N
# 17          1911             \N                    Drama
# 18          1911             51                      War
# 19          1911             \N                       \N
# 20          1911             \N                    Drama
# 21          1911             \N                       \N
# 22          1911             \N                       \N
# 23          1911             \N                       \N
# 24          1911             \N                    Drama
# 25          1911             \N                       \N
# 26          1911             \N                    Drama
# 27          1911             53                    Drama
# 28          1911             50  Biography,Drama,History
# 29          1913             \N                    Drama
# 31          1911             48                    Drama
# 32          1912             \N                    Drama
# 33          1912             \N              Documentary
# 34          1912             \N                       \N
# 35          1912             \N              Documentary
# ...          ...            ...                      ...
# 171795        \N             \N             Action,Drama
# 171796        \N             \N            Drama,Musical
# 171797      2018             \N                       \N
# 171798        \N             \N              Documentary
# 171799      2018             70                   Horror
# 171800        \N             \N  Horror,Mystery,Thriller
# 171801      2018             \N                 Thriller
# 171802      2016             \N              Documentary
# 171803        \N             80             Comedy,Drama
# 171804      2018             \N                 Thriller
# 171805        \N             \N     Comedy,Drama,Romance
# 171806        \N             90                 Thriller
# 171807      2018             73        Crime,Documentary
# 171808      2018             \N    Action,Crime,Thriller
# 171809      2010             79                    Music
# 171810      2016             72                   Horror
# 171813      2015             67                   Horror
# 171814        \N             \N                    Drama
# 171815      2018             99              Documentary
# 171816      2018            239                    Drama
# 171818        \N             \N                    Drama
# 171819      2017             \N              Documentary
# 171820        \N             \N                   Sci-Fi
# 171821        \N             \N                   Horror
# 171822      2018             65              Documentary
# 171823      2013             71                    Drama
# 171824      1984             92  Horror,Mystery,Thriller
# 171828        \N             \N                    Drama
# 171830      2019             \N  Action,Adventure,Comedy
# 171831      2015            100    Biography,Documentary
#
# [149352 rows x 5 columns]

# %%
# Split genres in 3 columns
df_us_movies_non_adult_result2[['genres1','genres2','genres3']]=df_us_movies_non_adult_result2.genres.str.split(',',expand=True)
# Out:
# C:\Users\guptav4\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:3140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
df_us_movies_non_adult_result2.head()
# Out:
#       tconst                    primaryTitle startYear runtimeMinutes  \
# 0  tt0000009                      Miss Jerry      1894             45
# 1  tt0000147   The Corbett-Fitzsimmons Fight      1897             20
# 2  tt0000630                          Hamlet      1908             \N
# 3  tt0000679  The Fairylogue and Radio-Plays      1908            120
# 4  tt0000886       Hamlet, Prince of Denmark      1910             \N
#
#                    genres
# 0                 Romance
# 1  Documentary,News,Sport
# 2                   Drama
# 3       Adventure,Fantasy
# 4                   Drama

# %%
len(df_us_movies_non_adult_result2)
# Out:
# 149352
